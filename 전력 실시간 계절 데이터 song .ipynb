# %%
import os 
# 필요 라이브러리 로드
from matplotlib import font_manager, rc
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import platform

if platform.system() == 'Windows':
# 윈도우인 경우 맑은 고딕 폰트 이용
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf"
                                           ).get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

#그래프에서 마이너스 기호가 표시되게 하는 설정입니다.
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('시군구_월_용도별사용.csv',encoding='utf-8')
df2 = pd.read_csv('시군구_월_용도별사용__2.csv',encoding='utf-8')

df_electricity = pd.read_csv('전국 시간별 전력 사용량(2013-2020).csv',encoding='cp949')
df_electricity_2021 = pd.read_csv('전국 시간별 전력 사용량(2021).csv',encoding='cp949')

# %%
# df2  biz  
# 시군구 용도별 사용 2  

fig, ax =plt.subplots()
ax.bar('biz','powerUsage',data=df2_sum)
plt.xticks(rotation=90)
plt.show()

# %%
df_electricity['연도']=df_electricity['날짜'].str.split('-').str.get(0)

# %%
#계절별 전력 사용량 차이  
df_electricity
# Out:
#               날짜     1시     2시     3시     4시     5시     6시     7시     8시  \
# 0     2013-01-01  60178  57862  56165  55135  54450  54401  54147  52467
# 1     2013-01-02  57067  55148  53983  53571  54027  55388  57753  60781
# 2     2013-01-03  66263  64233  63194  62461  62649  63396  65098  67745
# 3     2013-01-04  68403  66143  65051  64245  64152  64678  66494  68851
# 4     2013-01-05  68053  65801  64439  63437  63135  63250  63658  63441
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2917  2020-12-27  59378  56984  55568  55007  55175  55870  56503  56728
# 2918  2020-12-28  57699  55644  54525  54326  55082  57055  60570  66639
# 2919  2020-12-29  63123  60961  59911  59540  60098  61575  64587  69455
# 2920  2020-12-30  65936  63843  62679  62467  63020  64566  67875  73207
# 2921  2020-12-31  68206  66113  64646  64090  64286  65277  67840  72025
#
#          9시  ...    17시    18시    19시    20시    21시    22시    23시    24시  \
# ...

# %%
df_mean=df_electricity.mean().round(2).reset_index()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7660\3736522589.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_mean=df_electricity.mean().round(2).reset_index()

# %%
df_mean.columns=['시간','평균']

# %%
df_mean=df_mean.dropna(axis=0)
df_mean
# Out:
#      시간        평균
# 0    1시  57067.31
# 1    2시  54771.06
# 2    3시  53501.77
# 3    4시  52964.50
# 4    5시  53279.93
# 5    6시  54341.43
# 6    7시  56416.06
# 7    8시  59137.27
# 8    9시  63200.41
# 9   10시  64973.08
# 10  11시  65422.46
# 11  12시  65006.81
# 12  13시  62184.61
# 13  14시  64313.23
# 14  15시  65085.57
# 15  16시  65070.05
# 16  17시  65606.25
# 17  18시  65426.85
# 18  19시  65304.61
# 19  20시  64980.76
# 20  21시  63910.21
# 21  22시  62325.99
# 22  23시  61210.71
# 23  24시  60722.84

# %%
# df2  biz   

fig, ax =plt.subplots()
ax.bar('시간', '평균', data=df_mean)
plt.xticks(rotation=90)
plt.show()

# %%
df_mean_2021=df_electricity_2021.mean().round(2).reset_index()  # 평균값   데이터 프레임으로 만듬
df_mean_2021.columns=['시간','평균'] # 컬럼명 추가  
df_mean_2021
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7660\3223336043.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_mean_2021=df_electricity_2021.mean().round(2).reset_index()
#    index         0
# 0     1시  59474.80
# 1     2시  57329.79
# 2     3시  56135.91
# 3     4시  55614.44
# 4     5시  55880.70
# 5     6시  56997.46
# 6     7시  59288.52
# 7     8시  62379.49
# 8     9시  66197.04
# 9    10시  66787.78
# 10   11시  66688.90
# 11   12시  65718.81
# 12   13시  63559.94
# 13   14시  65511.54
# 14   15시  66633.57
# 15   16시  67687.98
# 16   17시  69304.77
# 17   18시  69692.64
# 18   19시  69767.67
# 19   20시  69215.06
# 20   21시  67728.03
# 21   22시  65563.46
# 22   23시  63563.59
# 23   24시  62972.37

# %%
#  시간별 2013 ~ 2020   평균   
#  시간별 2021  평균 
plt.figure(figsize=(6, 3)) # 크기 조정
plt.plot('시간', '평균', data=df_mean, linestyle='none', marker='o',  #  2013 ~ 2020 평균
         markersize=5, color='blue', alpha=0.4)
plt.xlabel('시간', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(rotation=90)
# plt.show() #  

plt.figure(figsize=(6, 3)) # 크기 조정
plt.plot('시간', '평균', data=df_mean_2021, linestyle='none', marker='o',  #2021 년도 평균 시간별  
         markersize=5, color='blue', alpha=0.4)
plt.xlabel('시간', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %%
df_electricity=df_electricity.drop(columns='월')

# %%
df_median=df_electricity.median().round(2).reset_index()  # 평균값   데이터 프레임으로 만듬
df_median.columns=['시간','평균'] # 컬럼명 추가  
df_median
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7660\3715399373.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_median=df_electricity.median().round(2).reset_index()  # 평균값   데이터 프레임으로 만듬
#      시간       평균
# 0    1시  56474.5
# 1    2시  54255.0
# 2    3시  53095.0
# 3    4시  52511.5
# 4    5시  52805.0
# 5    6시  53922.5
# 6    7시  56070.0
# 7    8시  58859.0
# 8    9시  63034.0
# 9   10시  64872.5
# 10  11시  65424.5
# 11  12시  65016.0
# 12  13시  61775.5
# 13  14시  64201.5
# 14  15시  65131.0
# 15  16시  65190.5
# 16  17시  65934.0
# 17  18시  65601.5
# 18  19시  65253.0
# 19  20시  64993.0
# 20  21시  63853.5
# 21  22시  62155.0
# 22  23시  60900.5
# 23  24시  60267.0

# %%
#  2013 ~ 2020 중앙값
# 2021  중앙 값 
plt.figure(figsize=(6, 3)) # 크기 조정
plt.plot('시간', '평균', data=df_median, linestyle='none', marker='o',  #  2013 ~ 2020 평균
         markersize=5, color='blue', alpha=1)
plt.xlabel('시간', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(rotation=90)
# plt.show() #  

plt.figure(figsize=(6, 3)) # 크기 조정
plt.plot('시간', '평균', data=df_median_2021, linestyle='none', marker='o',  #2021 년도 평균 시간별  
         markersize=5, color='blue', alpha=1)
plt.xlabel('시간', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(rotation=90)
plt.show() #  주택 사용량 증가

# %%
df_electricity_2021
# Out:
#              날짜     1시     2시     3시     4시     5시     6시     7시     8시  \
# 0    2021-01-01  64942  62593  60905  59889  59638  59936  60193  59982
# 1    2021-01-02  60658  58603  57309  56663  56733  57327  58378  59285
# 2    2021-01-03  61992  59723  58310  57599  57518  58073  58877  59373
# 3    2021-01-04  62078  60011  58936  58715  59233  61081  64908  71659
# 4    2021-01-05  67267  64957  63471  63136  63564  65045  68221  73685
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 360  2021-12-27  66465  64473  63140  62540  63122  65025  69117  76487
# 361  2021-12-28  71059  68940  67701  67076  67184  68598  72033  78270
# 362  2021-12-29  69651  67276  65941  65136  65534  66910  70309  75972
# 363  2021-12-30  68581  66406  65155  64639  65121  66804  70225  75906
# 364  2021-12-31  69373  67187  65955  65431  65798  67226  70163  75036
#
#         9시  ...    16시    17시    18시    19시    20시    21시    22시    23시  \
# ...

# %%
df_electricity_2021['월']=df_electricity_2021['날짜'].str.split('-').str.get(1).astype(int)

# %%
winter_2021=df_electricity_2021[(df_electricity_2021['월'] <= 2) | (df_electricity_2021['월'] == 12)]  # 겨울   12 1 2  
spring_2021=df_electricity_2021[df_electricity_2021['월'].isin([3, 4, 5])]  # 봄 3 4 5 
summer_2021=df_electricity_2021[df_electricity_2021['월'].isin([6, 7, 8])]# 가을
fall_2021=df_electricity_2021[df_electricity_2021['월'].isin([9, 10, 11])]# 겨울

# %%
fall_2021
# Out:
#              날짜     1시     2시     3시     4시     5시     6시     7시     8시  \
# 243  2021-09-01  60091  58273  57216  56597  56723  57769  60760  66271
# 244  2021-09-02  59773  57873  57012  56292  56259  57521  60291  64379
# 245  2021-09-03  59081  57394  56309  55846  56000  57283  59958  63871
# 246  2021-09-04  58770  56635  55452  54516  54419  54815  55427  55978
# 247  2021-09-05  54162  52047  50919  50221  50160  50645  51048  51072
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 329  2021-11-26  63081  60689  59418  59099  59813  61812  65041  69955
# 330  2021-11-27  63116  60579  59137  58532  58740  59558  61263  62339
# 331  2021-11-28  59269  56838  55446  54948  55141  56165  57191  57264
# 332  2021-11-29  57112  54969  53859  53860  54861  57062  61176  67365
# 333  2021-11-30  62375  60081  58992  58476  58993  60774  63927  68931
#
#         9시  ...    16시    17시    18시    19시    20시    21시    22시    23시  \
# ...

# %%
winter_2021.drop(columns=['날짜','월'],inplace=True)
spring_2021.drop(columns=['날짜','월'],inplace=True)
summer_2021.drop(columns=['날짜','월'],inplace=True)
fall_2021.drop(columns=['날짜','월'],inplace=True)
# 날짜  월  제거
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7660\1699404200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winter_2021.drop(columns=['날짜','월'],inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_7660\1699404200.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spring_2021.drop(columns=['날짜','월'],inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_7660\1699404200.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# 사계절  시간별 전력양 평균  2021 
winter_2021_mean=winter_2021.mean().round(2).reset_index()
winter_2021_mean.columns=['시간','평균']

spring_2021_mean=spring_2021.mean().round(2).reset_index()
spring_2021_mean.columns=['시간','평균']

summer_2021_mean=summer_2021.mean().round(2).reset_index()
summer_2021_mean.columns=['시간','평균']

fall_2021_mean=fall_2021.mean().round(2).reset_index()
fall_2021_mean.columns=['시간','평균']

winter_2021_mean,spring_2021_mean,summer_2021_mean,fall_2021_mean
# Out:
# (     시간        평균
#  0    1시  64817.51
#  1    2시  62532.84
#  2    3시  61216.19
#  3    4시  60715.98
#  4    5시  61130.34
#  5    6시  62457.96
#  6    7시  65072.52
#  7    8시  68937.88
#  8    9시  73818.70
#  9   10시  73716.78
#  10  11시  72761.26
#  11  12시  70815.82
#  12  13시  67645.86
#  13  14시  69296.90
#  14  15시  70255.51
#  15  16시  71383.51
#  16  17시  73387.63
#  17  18시  73535.34
#  18  19시  73179.34
#  19  20시  71626.13
#  20  21시  69879.87
#  21  22시  67740.66
#  22  23시  66814.53
#  23  24시  67864.49,
#       시간        평균
#  0    1시  56277.39
#  1    2시  54179.99
#  2    3시  53150.68
#  3    4시  52808.76
#  4    5시  53254.48
#  5    6시  54449.74
#  6    7시  56506.72
#  7    8시  58632.52
#  8    9시  61079.15
#  9   10시  60779.42
#  10  11시  60111.28
#  11  12시  58759.37
#  12  13시  56380.49
#  13  14시  57954.88
#  14  15시  58886.67
#  15  16시  60014.09
#  16  17시  61690.38
#  17  18시  62677.28
#  18  19시  63690.88
#  19  20시  64233.47
#  20  21시  63215.46
# ...

# %%
plt.figure(figsize=(6, 3)) # 겨울 
plt.plot('시간', '평균', data=winter_2021_mean, linestyle='none', marker='o',  #2021 년도 평균 시간별  
         markersize=5, color='blue', alpha=0.4)
plt.xlabel('겨울', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(rotation=90)
  

plt.figure(figsize=(6, 3)) # 봄
plt.plot('시간', '평균', data=spring_2021_mean, linestyle='none', marker='o',  #2021 년도 평균 시간별  
         markersize=5, color='blue', alpha=0.4)
plt.xlabel('봄', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(rotation=90)


plt.figure(figsize=(6, 3)) # 여름
plt.plot('시간', '평균', data=summer_2021_mean, linestyle='none', marker='o',  #2021 년도 평균 시간별  
         markersize=5, color='blue', alpha=0.4)
plt.xlabel('여름', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(rotation=90)


plt.figure(figsize=(6, 3)) # 가을
plt.plot('시간', '평균', data=summer_2021_mean, linestyle='none', marker='o',  #2021 년도 평균 시간별  
         markersize=5, color='blue', alpha=0.4)
plt.xlabel('가을', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(rotation=90)
plt.show()
